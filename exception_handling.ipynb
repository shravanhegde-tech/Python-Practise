# %%
try:
    a=b
except:
    print("An exception occurred")

# %%
try:
    a=b
except NameError as e:
    print(e)
    #print('give values to b and a')
else:
    print('No exception occurred')
finally:
    print('this will always execute')

# %%
try:
    a=open('package_filehandling.ipynb','r')
    f=a.read()
    a=b
    print(f)
except FileNotFoundError:
    print('file not found')
except Exception as e:
    print(e)
finally:
    if 'a' in locals() and not a.closed:
        a.close()
        print('file is closed')
    else:
        print('file is not opened')

# %%
#condition check
try:
    a=int(input('enter a number:'))
    if a<0:
        raise Exception('number shoundnt less than 0')
    print('given inputs are\n')
    for i in range(a):
        print(input())

except ValueError:
    print('please enter a valid number')

except Exception as e:
    print('cant print',e)
finally:
    print('executed successfully')
